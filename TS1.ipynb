# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales.csv")
df.head()
# Out:
#      saledate      MA   type  bedrooms
# 0  30/09/2007  441854  house         2
# 1  31/12/2007  441854  house         2
# 2  31/03/2008  441854  house         2
# 3  30/06/2008  441854  house         2
# 4  30/09/2008  451583  house         2

# %%
df.set_index('saledate',inplace=True)

# %%
df.head()
# Out:
#                 MA   type  bedrooms
# saledate
# 30/09/2007  441854  house         2
# 31/12/2007  441854  house         2
# 31/03/2008  441854  house         2
# 30/06/2008  441854  house         2
# 30/09/2008  451583  house         2

# %%
df.plot()
# Out:
# <Axes: xlabel='saledate'>

# %%
df.iloc[10]
# Out:
# MA          459222
# type         house
# bedrooms         2
# Name: 31/03/2010, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347 entries, 30/09/2007 to 30/09/2019
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MA        347 non-null    int64
#  1   type      347 non-null    object
#  2   bedrooms  347 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#                  MA    bedrooms
# count  3.470000e+02  347.000000
# mean   5.481320e+05    2.867435
# std    1.701934e+05    1.239875
# min    3.167510e+05    1.000000
# 25%    4.277395e+05    2.000000
# 50%    5.077440e+05    3.000000
# 75%    6.275155e+05    4.000000
# max    1.017752e+06    5.000000

# %%
df=df.sort_index()
df.index = pd.to_datetime(df.index)

# %%
df.index.year
# Out:
# Index([2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007,
#        ...
#        2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019],
#       dtype='int32', name='saledate', length=347)

# %%
df.groupby(df.index.year)['bedrooms'].mean()
# Out:
# saledate
# 2007    3.055556
# 2008    2.857143
# 2009    2.857143
# 2010    2.857143
# 2011    2.857143
# 2012    2.857143
# 2013    2.857143
# 2014    2.857143
# 2015    2.857143
# 2016    2.857143
# 2017    2.857143
# 2018    2.857143
# 2019    2.857143
# Name: bedrooms, dtype: float64

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df.tail()
# Out:
#                 MA   type  bedrooms
# saledate
# 2019-09-30  335449   unit         1
# 2019-09-30  631875  house         3
# 2019-09-30  970268  house         5
# 2019-09-30  424412   unit         2
# 2019-09-30  597884   unit         3

# %%
df.loc['2007-09-30':'2018-09-30']
# Out:
#                 MA   type  bedrooms
# saledate
# 2007-09-30  441854  house         2
# 2007-09-30  421291  house         3
# 2007-09-30  368817   unit         2
# 2007-09-30  518911   unit         3
# 2007-09-30  548969  house         4
# ...            ...    ...       ...
# 2018-09-30  603281   unit         3
# 2018-09-30  504318  house         2
# 2018-09-30  339220   unit         1
# 2018-09-30  624602  house         3
# 2018-09-30  426970   unit         2
#
# [314 rows x 3 columns]

# %%
plt.plot(df.index,df['MA'])

# %%
plt.plot(df.index,df['bedrooms'])

# %%
plt.hist(df['bedrooms'],bins=5,color='pink',edgecolor='black')
# Out:
# (array([ 48.,  99., 100.,  51.,  49.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)
