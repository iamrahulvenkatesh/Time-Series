# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("daily-min-temperatures.csv")
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
df.set_index('Date',inplace=True)
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df.index = pd.to_datetime(df.index)
df.index = df.index.map(lambda t:t.replace(year = 2023))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.index = pd.to_datetime(df.index)
#       2 df.index = df.index.map(lambda t:t.replace(year = 2023))
#
# NameError: name 'pd' is not defined

# %%
plt.plot(df.index,df['Temp'])
plt.xticks(rotation=90)
# Out:
# (array([3652., 4018., 4383., 4748., 5113., 5479., 5844., 6209., 6574.,
#         6940., 7305., 7670.]),
#  [Text(3652.0, 0, '1980'),
#   Text(4018.0, 0, '1981'),
#   Text(4383.0, 0, '1982'),
#   Text(4748.0, 0, '1983'),
#   Text(5113.0, 0, '1984'),
#   Text(5479.0, 0, '1985'),
#   Text(5844.0, 0, '1986'),
#   Text(6209.0, 0, '1987'),
#   Text(6574.0, 0, '1988'),
#   Text(6940.0, 0, '1989'),
#   Text(7305.0, 0, '1990'),
#   Text(7670.0, 0, '1991')])

# %%
plt.scatter(df.index,df['Temp'])

# %%
pd.plotting.autocorrelation_plot(df['Temp'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
plt.hist(df['Temp'],bins=10)
# Out:
# (array([ 53., 181., 564., 862., 830., 670., 347., 102.,  32.,   9.]),
#  array([ 0.  ,  2.63,  5.26,  7.89, 10.52, 13.15, 15.78, 18.41, 21.04,
#         23.67, 26.3 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.kdeplot(df['Temp'],fill=True)
# Out:
# <Axes: xlabel='Temp', ylabel='Density'>

# %%
plt.boxplot(df['Temp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2c9c1be00>,
#   <matplotlib.lines.Line2D at 0x1d2c9c50140>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d2c9c503b0>,
#   <matplotlib.lines.Line2D at 0x1d2c9c50680>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2c9c08260>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2c9c50950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2c9c50bf0>],
#  'means': []}

# %%
sns.heatmap(df,cmap='coolwarm')
# Out:
# <Axes: ylabel='Date'>
